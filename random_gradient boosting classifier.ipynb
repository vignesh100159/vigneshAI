# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv("C:/Users/Yash Bohra/Desktop/data/kc_house_data.csv")

# %%
data.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
data.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
labels = data['price']
conv_dates = [1 if values == 2014 else 0 for values in data.date ]
data['date'] = conv_dates

train1 = data.drop(['id', 'price'],axis=1)
X = data.drop(['id', 'price'],axis=1)
y = data["price"]

# %%
train1.head(10)
# Out:
#    date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0     0         3       1.00         1180      5650     1.0           0     0
# 1     0         3       2.25         2570      7242     2.0           0     0
# 2     0         2       1.00          770     10000     1.0           0     0
# 3     0         4       3.00         1960      5000     1.0           0     0
# 4     0         3       2.00         1680      8080     1.0           0     0
# 5     0         4       4.50         5420    101930     1.0           0     0
# 6     0         3       2.25         1715      6819     2.0           0     0
# 7     0         3       1.50         1060      9711     1.0           0     0
# 8     0         3       1.00         1780      7470     1.0           0     0
# 9     0         3       2.50         1890      6560     2.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test = train_test_split(train1 , labels , test_size = 0.10,random_state =2)

# %%
X.head(10)
# Out:
#    date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0     0         3       1.00         1180      5650     1.0           0     0
# 1     0         3       2.25         2570      7242     2.0           0     0
# 2     0         2       1.00          770     10000     1.0           0     0
# 3     0         4       3.00         1960      5000     1.0           0     0
# 4     0         3       2.00         1680      8080     1.0           0     0
# 5     0         4       4.50         5420    101930     1.0           0     0
# 6     0         3       2.25         1715      6819     2.0           0     0
# 7     0         3       1.50         1060      9711     1.0           0     0
# 8     0         3       1.00         1780      7470     1.0           0     0
# 9     0         3       2.50         1890      6560     2.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# ...

# %%
train1.shape
# Out:
# (21613, 19)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
reg.score(X_test,y_test)
# Out:
# 0.7320342760357841

# %%
from sklearn import ensemble
clf = ensemble.GradientBoostingRegressor(n_estimators = 400, max_depth = 5, min_samples_split = 2,
          learning_rate = 0.1, loss = 'ls')

# %%
clf.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=5, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=400, n_iter_no_change=None, presort='auto',
#              random_state=None, subsample=1.0, tol=0.0001,
#              validation_fraction=0.1, verbose=0, warm_start=False)

# %%
clf.score(X_test,y_test)
# Out:
# 0.9202042887611547

# %%
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn import metrics

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(clf,X,y,cv=10,scoring='r2').mean()
# Out:
# 0.895641720492

# %%
from sklearn.feature_selection import RFE

# %%
selector = RFE(clf, 8, step=1)

# %%
selector = selector.fit(X, y)

# %%
selector.ranking_
# Out:
# array([12, 11,  6,  1,  4, 10,  1,  3,  8,  1,  1,  7,  1,  9,  2,  1,  1,
#         1,  5])

# %%
train1.head(10)
# Out:
#    date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0     0         3       1.00         1180      5650     1.0           0     0
# 1     0         3       2.25         2570      7242     2.0           0     0
# 2     0         2       1.00          770     10000     1.0           0     0
# 3     0         4       3.00         1960      5000     1.0           0     0
# 4     0         3       2.00         1680      8080     1.0           0     0
# 5     0         4       4.50         5420    101930     1.0           0     0
# 6     0         3       2.25         1715      6819     2.0           0     0
# 7     0         3       1.50         1060      9711     1.0           0     0
# 8     0         3       1.00         1780      7470     1.0           0     0
# 9     0         3       2.50         1890      6560     2.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# ...

# %%
train2 = train1.drop(['date','bedrooms','bathrooms','sqft_lot','floors','view','condition','sqft_basement','yr_renovated','zipcode','sqft_lot15'],axis=1)

# %%
X=train2

# %%
X
# Out:
#        sqft_living  waterfront  grade  sqft_above  yr_built      lat     long  \
# 0             1180           0      7        1180      1955  47.5112 -122.257
# 1             2570           0      7        2170      1951  47.7210 -122.319
# 2              770           0      6         770      1933  47.7379 -122.233
# 3             1960           0      7        1050      1965  47.5208 -122.393
# 4             1680           0      8        1680      1987  47.6168 -122.045
# 5             5420           0     11        3890      2001  47.6561 -122.005
# 6             1715           0      7        1715      1995  47.3097 -122.327
# 7             1060           0      7        1060      1963  47.4095 -122.315
# 8             1780           0      7        1050      1960  47.5123 -122.337
# 9             1890           0      7        1890      2003  47.3684 -122.031
# 10            3560           0      8        1860      1965  47.6007 -122.145
# ...

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y, test_size = 0.10,random_state =2)

# %%
from sklearn import ensemble
clf2 = ensemble.GradientBoostingRegressor(n_estimators = 400, max_depth = 5, min_samples_split = 2,
          learning_rate = 0.1, loss = 'ls')

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(clf2,X,y,cv=10,scoring='r2').mean()
# Out:
# 0.8803323844092757

# %%
from sklearn.feature_selection import RFECV
selector = RFECV(clf2, step=1, cv=5)
selector = selector.fit(X, y)

# %%
selector.score(X,y)
# Out:
# 0.9585154351092801

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=None,
#            oob_score=False, random_state=42, verbose=0, warm_start=False)

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(X_test)

# %%
rf.score(X_test,y_test)
# Out:
# 0.8939787180207586

# %%
from sklearn.feature_selection import RFECV
selector1 = RFECV(rf, step=1, cv=5)
selector1 = selector1.fit(X, y)

# %%
selector1.score(X,y)
# Out:
# 0.9585154351092801

# %%
from sklearn.ensemble import VotingRegressor

# %%
eclf = VotingRegressor(estimators=[('rf', rf), ('Gradient boost',selector)],voting='soft', weights=[1,2,3],
       flatten_transform=True)
eclf = eclf.fit(X_train, y_train)
y_pred=eclf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-ba14b6566550> in <module>
# ----> 1 eclf = VotingRegressor(estimators=[('rf', rf), ('Gradient boost',selector)],voting='soft', weights=[1,2,3],
#       2        flatten_transform=True)
#       3 eclf = eclf.fit(X_train, y_train)
#       4 y_pred=eclf.predict(X_test)
#
# NameError: name 'VotingRegressor' is not defined
